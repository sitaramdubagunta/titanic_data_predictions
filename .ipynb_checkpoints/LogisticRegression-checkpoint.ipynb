# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
titanic  = pd.read_csv('titanic.csv')

titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.shape
# Out:
# (891, 12)

# %% [markdown]
# #### Pclass feature describes the ticket class 1 is first class 2 is second class and 3 is third class
# #### SibSp feature describes the siblings / spouses number of the person  aboard the titanic
# #### parch describes the parents / children of the person on the titanic
# #### ticket is the ticket number
# #### fare is the price in usd
# #### cabin is the cabin number
# #### embarked-Port of Embarkation-C = Cherbourg, Q = Queenstown, S = Southampton

# %% [markdown]
# # checking for null values

# %%
titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic.loc[titanic.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
titanic.Age  =  titanic.Age.fillna(titanic.Age.median() )

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic = titanic.drop(['Cabin' , 'PassengerId' , 'Name'] , axis  = 1)

# %%
titanic.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    2
# dtype: int64

# %%
titanic.Embarked.dropna()
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 889, dtype: object

# %%
titanic
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0           0       3    male  22.0      1      0         A/5 21171   7.2500
# 1           1       1  female  38.0      1      0          PC 17599  71.2833
# 2           1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3           1       1  female  35.0      1      0            113803  53.1000
# 4           0       3    male  35.0      0      0            373450   8.0500
# ..        ...     ...     ...   ...    ...    ...               ...      ...
# 886         0       2    male  27.0      0      0            211536  13.0000
# 887         1       1  female  19.0      0      0            112053  30.0000
# 888         0       3  female  28.0      1      2        W./C. 6607  23.4500
# 889         1       1    male  26.0      0      0            111369  30.0000
# 890         0       3    male  32.0      0      0            370376   7.7500
#
#     Embarked
# 0          S
# 1          C
# ...

# %% [markdown]
# # analysis of the categorical data

# %%
titanic['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
titanic['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
titanic['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
titanic['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
plt.subplot(2,2,1)


plt.bar(titanic['Embarked'].value_counts().index ,titanic['Embarked'].value_counts().values )

plt.subplot(2,2,2)
plt.bar(titanic['Sex'].value_counts().index ,titanic['Sex'].value_counts().values )
plt.subplot(2,2,3)
plt.bar(titanic['Pclass'].value_counts().index ,titanic['Pclass'].value_counts().values )
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# #### according to this data we understand that the majority of the passangers aboard were male , 3rd class passengers , this might play a key factor in deciding if they have deceased during the accident or not

# %% [markdown]
# ## Feature engineering the ticket feature

# %%
 titanic.groupby('Ticket')['Ticket'].count().sort_values(ascending  = False)
# Out:
# Ticket
# 1601        7
# CA. 2343    7
# 347082      7
# CA 2144     6
# 347088      6
#            ..
# 345572      1
# 345364      1
# 343276      1
# 343275      1
# 347464      1
# Name: Ticket, Length: 681, dtype: int64

# %% [markdown]
# ####  here we can see many people have 1 single ticket this might be useful for our model

# %%
titanic['count_ticket']  =  titanic.groupby('Ticket')['Ticket'].transform('count')
titanic
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0           0       3    male  22.0      1      0         A/5 21171   7.2500
# 1           1       1  female  38.0      1      0          PC 17599  71.2833
# 2           1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3           1       1  female  35.0      1      0            113803  53.1000
# 4           0       3    male  35.0      0      0            373450   8.0500
# ..        ...     ...     ...   ...    ...    ...               ...      ...
# 886         0       2    male  27.0      0      0            211536  13.0000
# 887         1       1  female  19.0      0      0            112053  30.0000
# 888         0       3  female  28.0      1      2        W./C. 6607  23.4500
# 889         1       1    male  26.0      0      0            111369  30.0000
# 890         0       3    male  32.0      0      0            370376   7.7500
#
#     Embarked  count_ticket
# ...

# %% [markdown]
# ####  the reason why a few people share the same TICKET is because they might be part of the same group or family

# %%
titanic.Ticket.apply(lambda x :  'PC' if x.startswith('PC') else 'Other' ).value_counts()
# Out:
# Ticket
# Other    831
# PC        60
# Name: count, dtype: int64

# %% [markdown]
# ### It is intresting to note that there are many people with tickets starting with PC and W.C/ and so on but for now we wont group it based on that instead we will be dropping the tickets coloumn

# %%
titanic = titanic.drop(['Ticket' ] , axis = 1)

# %% [markdown]
# # Encoding the categorical data (one hot encoding)

# %% [markdown]
# #### we will be using one hot encoding over label encoding since in label encoding for example in EMBARKED (S,C,Q) label encoding stores it as (1,2,3)
# #### which might give a bias towards Q if we use label encoding

# %%
titanic = pd.get_dummies(titanic , drop_first = True)

# %%
titanic
# Out:
#      Survived  Pclass   Age  SibSp  Parch     Fare  count_ticket  Sex_male  \
# 0           0       3  22.0      1      0   7.2500             1      True
# 1           1       1  38.0      1      0  71.2833             1     False
# 2           1       3  26.0      0      0   7.9250             1     False
# 3           1       1  35.0      1      0  53.1000             2     False
# 4           0       3  35.0      0      0   8.0500             1      True
# ..        ...     ...   ...    ...    ...      ...           ...       ...
# 886         0       2  27.0      0      0  13.0000             1      True
# 887         1       1  19.0      0      0  30.0000             1     False
# 888         0       3  28.0      1      2  23.4500             2     False
# 889         1       1  26.0      0      0  30.0000             1      True
# 890         0       3  32.0      0      0   7.7500             1      True
#
#      Embarked_Q  Embarked_S
# 0         False        True
# ...

# %% [markdown]
# ## checking correlation in the dataframe

# %%
dfcorr = titanic.corr()
dfcorr
# Out:
#               Survived    Pclass       Age     SibSp     Parch      Fare  \
# Survived      1.000000 -0.338481 -0.064910 -0.035322  0.081629  0.257307
# Pclass       -0.338481  1.000000 -0.339898  0.083081  0.018443 -0.549500
# Age          -0.064910 -0.339898  1.000000 -0.233296 -0.172482  0.096688
# SibSp        -0.035322  0.083081 -0.233296  1.000000  0.414838  0.159651
# Parch         0.081629  0.018443 -0.172482  0.414838  1.000000  0.216225
# Fare          0.257307 -0.549500  0.096688  0.159651  0.216225  1.000000
# count_ticket  0.038247 -0.002633 -0.218669  0.661622  0.593076  0.345541
# Sex_male     -0.543351  0.131900  0.081163 -0.114631 -0.245489 -0.182333
# Embarked_Q    0.003650  0.221009 -0.031415 -0.026354 -0.081228 -0.117216
# Embarked_S   -0.155660  0.081720 -0.014665  0.070941  0.063036 -0.166603
#
#               count_ticket  Sex_male  Embarked_Q  Embarked_S
# Survived          0.038247 -0.543351    0.003650   -0.155660
# ...

# %%
sns.heatmap(dfcorr)
# Out:
# <Axes: >

# %% [markdown]
# #### here males have a very strong negetive correlation with survived that means not many males have survived the crash
#
# #### embarked and count_ticket have little to no change in the regression model suggesting that can be removed as well
#
# #### Pclass and fare have strong negetive correlation  with survived that means that people with a better ticket had a better chance of survival

# %% [markdown]
# ### pclass and fare have strong correlation to each other , pclass is redundant ,this is expected since for a better class ticket the fare is higher

# %%
sns.scatterplot(data=titanic, x='Pclass', y='Fare', hue='Survived')
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %% [markdown]
# #### this scatter plot shows as the class goes from 1st to 3rd the fares decrease
# #### and also we can see many of the 1st class passangers have survived while the majority of the deceased belong to 3rd class

# %% [markdown]
# # Feature selection

# %%
titanic = titanic.drop(['count_ticket' ,'SibSp'] , axis = 1)

# %%
titanic
# Out:
#      Survived  Pclass   Age  Parch     Fare  Sex_male  Embarked_Q  Embarked_S
# 0           0       3  22.0      0   7.2500      True       False        True
# 1           1       1  38.0      0  71.2833     False       False       False
# 2           1       3  26.0      0   7.9250     False       False        True
# 3           1       1  35.0      0  53.1000     False       False        True
# 4           0       3  35.0      0   8.0500      True       False        True
# ..        ...     ...   ...    ...      ...       ...         ...         ...
# 886         0       2  27.0      0  13.0000      True       False        True
# 887         1       1  19.0      0  30.0000     False       False        True
# 888         0       3  28.0      2  23.4500     False       False        True
# 889         1       1  26.0      0  30.0000      True       False       False
# 890         0       3  32.0      0   7.7500      True        True       False
#
# [891 rows x 8 columns]

# %% [markdown]
# # Feature scaling using normalization

# %% [markdown]
# #### using normalizaition and standardization gave us rougly the same metrics , but since i prefer the range to be in 0 to 1 i took normalization here

# %%
sns.histplot( titanic['Fare'],kde = True )
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %% [markdown]
# ### (Before feature scaling) we can see the Fare graph is skewed to the left (that means majority of the people had cheaper tickets)

# %%
feature = titanic.iloc[ :, 1:]
target = titanic.iloc[: ,0]
feature_toscale  = ['Age' , 'Fare']

for column in feature_toscale:

    titanic[column] = (titanic[column] - titanic[column].min() ) / titanic[column].max() - titanic[column].min()

# %%
titanic
# Out:
#      Survived  Pclass      Age  Parch      Fare  Sex_male  Embarked_Q  \
# 0           0       3 -0.15025      0  0.014151      True       False
# 1           1       1  0.04975      0  0.139136     False       False
# 2           1       3 -0.10025      0  0.015469     False       False
# 3           1       1  0.01225      0  0.103644     False       False
# 4           0       3  0.01225      0  0.015713      True       False
# ..        ...     ...      ...    ...       ...       ...         ...
# 886         0       2 -0.08775      0  0.025374      True       False
# 887         1       1 -0.18775      0  0.058556     False       False
# 888         0       3 -0.07525      2  0.045771     False       False
# 889         1       1 -0.10025      0  0.058556      True       False
# 890         0       3 -0.02525      0  0.015127      True        True
#
#      Embarked_S
# 0          True
# 1         False
# 2          True
# 3          True
# 4          True
# ..          ...
# ...

# %%
sns.histplot( titanic['Fare'],kde = True )
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %% [markdown]
# ### even after standardizing it preserves the skewness of the graph , this is important since we know majority of them had cheaper tickerts

# %%
for i , column in enumerate(titanic , 1):
    plt.subplot(4,4,i)
    sns.boxplot(titanic[column])
plt.tight_layout()

# %% [markdown]
# #### boxplots showing us the distribution of data , this was very useful for me when i was feature scaling , as i got to know the ranges of age and fare

# %%
titanic.shape # shows us the shape after feature scaling
# Out:
# (891, 8)

# %% [markdown]
# # splitting it into test and training set

# %%
df_shuffled  = titanic.sample(frac = 1 ,random_state = 43 ).reset_index(drop = True)
## taking a random train data split of 80% of 891 samples
X_train = df_shuffled.iloc[:int(0.8*titanic.shape[0]) ,1: ]
X_test = df_shuffled.iloc[int(0.8*titanic.shape[0]): ,1: ]
Y_train  = df_shuffled.iloc[:int(0.8*titanic.shape[0]) ,0 ]
Y_test  = df_shuffled.iloc[int(0.8*titanic.shape[0]): ,0 ]
X_train
# Out:
#      Pclass      Age  Parch      Fare  Sex_male  Embarked_Q  Embarked_S
# 0         3 -0.12525      0  0.018543      True       False        True
# 1         1 -0.22525      1  0.076904     False       False        True
# 2         2 -0.20025      0  0.022447      True       False        True
# 3         3 -0.15025      0  0.015127     False       False        True
# 4         3 -0.38775      2  0.061264      True       False        True
# ..      ...      ...    ...       ...       ...         ...         ...
# 707       3  0.45600      0  0.015127      True        True       False
# 708       1  0.19975      1  0.483128     False       False       False
# 709       3 -0.13775      0  0.014737     False       False        True
# 710       2 -0.38775      1  0.036598      True       False        True
# 711       1  0.03725      1  0.102579      True       False        True
#
# [712 rows x 7 columns]

# %%
import numpy as np


class LogisticRegression:

    def __init__(self,lr = 0.1 , n_iters = 2000 , lambda_value = 1):
        self.lr = lr
        self.n_iters = n_iters
        self.lambda_value = lambda_value
        self.weights = None
        self.bias = None
        self.costs = []


    def sigmoid(self,Z):
        Z = np.array(Z,dtype=float)
        return 1/(1+np.exp(-Z))
    
    def fit(self , X , Y):

        np_samples , np_features  = X.shape
        self.weights = np.zeros(np_features)
        self.bias = 0
        #starting gradient descent at [0,0,0, ..., 0] , 0
        for _ in range(self.n_iters):
            y_prediction  =  np.dot(X,self.weights) + self.bias
            predictions  = self.sigmoid(y_prediction)

            dw  = (1/np_samples)*np.dot(X.T,  predictions  - Y ) + (self.lambda_value / np_samples)*self.weights
                       #regularized values of w1,w2,w3,w4,w5,...
            db = (1/np_samples)*np.sum(predictions - Y)

            self.weights  = self.weights - self.lr*dw
            self.bias  = self.bias - self.lr*db
            cost = - (1 / np_samples) * np.sum(Y * np.log(predictions ) + (1 - Y) * np.log(1 - predictions ))
            self.costs.append(cost)

        


    def predict(self,X):
        linear_prediction  = np.dot(X,self.weights)+self.bias
        predictions  = self.sigmoid(linear_prediction)  
        return [ 1 if i > 0.5 else 0 for i in predictions] ## this is a list comprehension iterating over predictions and setting the value to 1 if greater than threshold
        '''
        while checking the values of precision to take when i got the value of threshold to 0.4 the value of accuracy decreases but recall INCREASES
        that means it has less false negetives

        while i got the threshold to 0.6 the precision increased because since fewer positives are there , the false positives obviously decreases
        but when we took F1 score it was less than what it was for threshold of 0.5

        this is why f1 score is  a better metric as in the above example we took how we can't really depend on precision and recall 
        '''

# %%
class Metrics:

    def __init__(self , y_actual , y_pred):
        self.y_actual = np.array(y_actual)
        self.y_pred = np.array(y_pred)
        self.TP = np.sum((self.y_actual == 1) & (self.y_pred == 1))
        self.TN = np.sum((self.y_actual == 0) & (self.y_pred == 0))
        self.FP = np.sum((self.y_actual == 0) & (self.y_pred == 1))
        self.FN = np.sum((self.y_actual == 1) & (self.y_pred == 0))
   
    def accuracy(self):
        
        return (self.TP + self.TN) / (self.TP + self.TN + self.FP + self.FN)
        
    def precision(self):
         return self.TP / (self.TP + self.FP)
    def recall(self):
        return self.TP / (self.TP + self.FN)

    def f1_score(self):
        precision = self.precision()
        recall = self.recall()
        return 2 * (precision * recall) / (precision + recall)

# %%
logreg = LogisticRegression()
logreg.fit(X_train , Y_train)
y_pred  = logreg.predict(X_test)




metric = Metrics(Y_test , y_pred)
print('accuracy'  , metric.accuracy())
print('precision' ,metric.precision())
print('recall' , metric.recall())
print('f1_score' , metric.f1_score())
# Out:
# accuracy 0.8491620111731844
# precision 0.8615384615384616
# recall 0.7567567567567568
# f1_score 0.8057553956834532

# %% [markdown]
# # cost vs epoch graph

# %%
plt.plot(range(logreg.n_iters) , logreg.costs , label = "cost vs epoch")
plt.xlabel("number of epochs")
plt.ylabel("cost function")
plt.show()
